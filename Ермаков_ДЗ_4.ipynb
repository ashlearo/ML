# %% [markdown]
# <a href="https://colab.research.google.com/github/ashlearo/ML/blob/main/%D0%95%D1%80%D0%BC%D0%B0%D0%BA%D0%BE%D0%B2_%D0%94%D0%97_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f72ed2bc-1632-4728-a509-4fd403c31ee2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f72ed2bc-1632-4728-a509-4fd403c31ee2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving adult_data.csv to adult_data.csv

# %%
adult_data = pd.read_csv('adult_data.csv', header='infer')
adult_data.head(100)
# Out:
#     age         workclass  fnlwgt  ... hours-per-week  native-country salary
# 0    39         State-gov   77516  ...             40   United-States  <=50K
# 1    50  Self-emp-not-inc   83311  ...             13   United-States  <=50K
# 2    38           Private  215646  ...             40   United-States  <=50K
# 3    53           Private  234721  ...             40   United-States  <=50K
# 4    28           Private  338409  ...             40            Cuba  <=50K
# ..  ...               ...     ...  ...            ...             ...    ...
# 95   29         Local-gov  115585  ...             50   United-States  <=50K
# 96   48  Self-emp-not-inc  191277  ...             60   United-States   >50K
# 97   37           Private  202683  ...             48   United-States   >50K
# 98   48           Private  171095  ...             40         England  <=50K
# 99   32       Federal-gov  249409  ...             40   United-States  <=50K
#
# [100 rows x 15 columns]

# %%
adult_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
adult_data.describe()
# Out:
#                 age        fnlwgt  ...  capital-loss  hours-per-week
# count  32561.000000  3.256100e+04  ...  32561.000000    32561.000000
# mean      38.581647  1.897784e+05  ...     87.303830       40.437456
# std       13.640433  1.055500e+05  ...    402.960219       12.347429
# min       17.000000  1.228500e+04  ...      0.000000        1.000000
# 25%       28.000000  1.178270e+05  ...      0.000000       40.000000
# 50%       37.000000  1.783560e+05  ...      0.000000       40.000000
# 75%       48.000000  2.370510e+05  ...      0.000000       45.000000
# max       90.000000  1.484705e+06  ...   4356.000000       99.000000
#
# [8 rows x 6 columns]

# %%
adult_data['native-country'].tolist()
s = adult_data['native-country'].tolist()
adult_data['native-country']
print(s)
# Out:
# ['United-States', 'United-States', 'United-States', 'United-States', 'Cuba', 'United-States', 'Jamaica', 'United-States', 'United-States', 'United-States', 'United-States', 'India', 'United-States', 'United-States', '?', 'Mexico', 'United-States', 'United-States', 'United-States', 'United-States', 'United-States', 'United-States', 'United-States', 'United-States', 'United-States', 'United-States', 'United-States', 'South', 'United-States', 'United-States', 'United-States', 'United-States', 'United-States', 'United-States', 'United-States', 'Puerto-Rico', 'United-States', 'United-States', '?', 'United-States', 'United-States', 'United-States', 'United-States', 'United-States', 'United-States', 'United-States', 'United-States', 'United-States', 'United-States', 'United-States', 'United-States', '?', 'Honduras', 'United-States', 'United-States', 'United-States', 'Mexico', 'Puerto-Rico', 'United-States', 'United-States', 'United-States', '?', 'United-States', 'United-States', 'United-Sta
# ...

# %%
native-country_flag	= set adult_data['native-country'].tolist()
native-country_flag
# Out:
#   File "<ipython-input-35-5394fa6ea2a9>", line 1
#     native-country_flag	= set adult_data['native-country'].tolist()
#                        	               ^
# SyntaxError: invalid syntax

# %%
#g1 = adult_data.isin(['Germany'])
adult_data[adult_data['native-country'].isin(['Germany'])]
# Out:
#        age         workclass  fnlwgt  ... hours-per-week  native-country salary
# 122     30           Private   77143  ...             40         Germany  <=50K
# 280     22           Private   34918  ...             15         Germany  <=50K
# 767     22           Private  151790  ...             30         Germany  <=50K
# 1009    26           Private  109186  ...             50         Germany  <=50K
# 1142    59       Federal-gov  212448  ...             40         Germany  <=50K
# ...    ...               ...     ...  ...            ...             ...    ...
# 32074   30           Private  318749  ...             35         Germany  <=50K
# 32101   45           Private  174794  ...             56         Germany  <=50K
# 32141   34           Private  193344  ...             40         Germany  <=50K
# 32236   26           Private  323044  ...             45         Germany   >50K
# 32341   74  Self-emp-not-inc  199136  ...              8         Germany   >50K
#
# ...

# %%
germ_all = adult_data[adult_data['native-country'] == 'Germany']
germ_all
# Out:
#        age         workclass  fnlwgt  ... hours-per-week  native-country salary
# 122     30           Private   77143  ...             40         Germany  <=50K
# 280     22           Private   34918  ...             15         Germany  <=50K
# 767     22           Private  151790  ...             30         Germany  <=50K
# 1009    26           Private  109186  ...             50         Germany  <=50K
# 1142    59       Federal-gov  212448  ...             40         Germany  <=50K
# ...    ...               ...     ...  ...            ...             ...    ...
# 32074   30           Private  318749  ...             35         Germany  <=50K
# 32101   45           Private  174794  ...             56         Germany  <=50K
# 32141   34           Private  193344  ...             40         Germany  <=50K
# 32236   26           Private  323044  ...             45         Germany   >50K
# 32341   74  Self-emp-not-inc  199136  ...              8         Germany   >50K
#
# ...

# %%
germ_age = germ_all[germ_all['age'] > 40]
germ_age
# Out:
#        age         workclass  fnlwgt  ... hours-per-week  native-country salary
# 1142    59       Federal-gov  212448  ...             40         Germany  <=50K
# 1346    61      Self-emp-inc  134768  ...             50         Germany   >50K
# 1425    46           Private  134727  ...             43         Germany  <=50K
# 3159    58           Private  235624  ...             40         Germany   >50K
# 4354    53       Federal-gov  199720  ...             60         Germany   >50K
# 4704    60  Self-emp-not-inc   88570  ...             15         Germany   >50K
# 4748    51           Private  183611  ...             55         Germany  <=50K
# 5143    57           Private  372967  ...             70         Germany  <=50K
# 5705    43  Self-emp-not-inc  240170  ...             50         Germany  <=50K
# 5796    47       Federal-gov   34845  ...             45         Germany   >50K
# 6344    46       Federal-gov   80057  ...             40         Germany   >50K
# ...

# %%
germ_all_50K = germ_age[germ_age['salary'] == '>50K']
germ_all_50K
# Out:
#        age         workclass  fnlwgt  ... hours-per-week  native-country salary
# 1346    61      Self-emp-inc  134768  ...             50         Germany   >50K
# 3159    58           Private  235624  ...             40         Germany   >50K
# 4354    53       Federal-gov  199720  ...             60         Germany   >50K
# 4704    60  Self-emp-not-inc   88570  ...             15         Germany   >50K
# 5796    47       Federal-gov   34845  ...             45         Germany   >50K
# 6344    46       Federal-gov   80057  ...             40         Germany   >50K
# 8068    49           Private  169711  ...             40         Germany   >50K
# 10415   48           Private   73434  ...             40         Germany   >50K
# 11017   54           Private  139703  ...             40         Germany   >50K
# 11093   55           Private  124808  ...             50         Germany   >50K
# 12030   45           Private  217654  ...             40         Germany   >50K
# ...

# %%
germ_all_50K.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 1346 to 32341
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             25 non-null     int64
#  1   workclass       25 non-null     object
#  2   fnlwgt          25 non-null     int64
#  3   education       25 non-null     object
#  4   education-num   25 non-null     int64
#  5   marital-status  25 non-null     object
#  6   occupation      25 non-null     object
#  7   relationship    25 non-null     object
#  8   race            25 non-null     object
#  9   sex             25 non-null     object
#  10  capital-gain    25 non-null     int64
#  11  capital-loss    25 non-null     int64
#  12  hours-per-week  25 non-null     int64
#  13  native-country  25 non-null     object
#  14  salary          25 non-null     object
# dtypes: int64(6), object(9)
# memory usage: 3.1+ KB

# %%
germ_all_50K.median()
# Out:
# age                   52.0
# fnlwgt            159049.0
# education-num         11.0
# capital-gain           0.0
# capital-loss           0.0
# hours-per-week        40.0
# dtype: float64

# %%
germ_all_50K.std()
# Out:
# age                   7.525069
# fnlwgt            84062.290452
# education-num         2.392349
# capital-gain       5153.609278
# capital-loss        645.921040
# hours-per-week       14.268497
# dtype: float64

# %%
adult_data.mean()
# Out:
# age                   38.581647
# fnlwgt            189778.366512
# education-num         10.080679
# capital-gain        1077.648844
# capital-loss          87.303830
# hours-per-week        40.437456
# dtype: float64

# %%
adult_data.quantile(0.75)
# Out:
# age                   48.0
# fnlwgt            237051.0
# education-num         12.0
# capital-gain           0.0
# capital-loss           0.0
# hours-per-week        45.0
# Name: 0.75, dtype: float64

# %%
adult_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
robot1 = adult_data[adult_data['hours-per-week'] > 45]
robot1
# Out:
#        age         workclass  fnlwgt  ... hours-per-week  native-country salary
# 8       31           Private   45781  ...             50   United-States   >50K
# 10      37           Private  280464  ...             80   United-States   >50K
# 13      32           Private  205019  ...             50   United-States  <=50K
# 18      38           Private   28887  ...             50   United-States  <=50K
# 20      40           Private  193524  ...             60   United-States   >50K
# ...    ...               ...     ...  ...            ...             ...    ...
# 32536   34           Private  160216  ...             55   United-States   >50K
# 32537   30           Private  345898  ...             46   United-States  <=50K
# 32543   45         Local-gov  119199  ...             48   United-States  <=50K
# 32548   65  Self-emp-not-inc   99359  ...             60   United-States  <=50K
# 32550   43  Self-emp-not-inc   27242  ...             50   United-States  <=50K
#
# ...

# %%
 robot2 = robot1[robot1['age'] > 39]
 robot2
# Out:
#        age         workclass  fnlwgt  ... hours-per-week  native-country salary
# 20      40           Private  193524  ...             60   United-States   >50K
# 27      54                 ?  180211  ...             60           South   >50K
# 52      47           Private   51835  ...             60        Honduras   >50K
# 53      50       Federal-gov  251585  ...             55   United-States   >50K
# 54      47      Self-emp-inc  109832  ...             60   United-States  <=50K
# ...    ...               ...     ...  ...            ...             ...    ...
# 32519   46           Private  364548  ...             48   United-States   >50K
# 32533   54           Private  337992  ...             50           Japan   >50K
# 32543   45         Local-gov  119199  ...             48   United-States  <=50K
# 32548   65  Self-emp-not-inc   99359  ...             60   United-States  <=50K
# 32550   43  Self-emp-not-inc   27242  ...             50   United-States  <=50K
#
# ...
