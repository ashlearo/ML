# %% [markdown]
# <a href="https://colab.research.google.com/github/ashlearo/ML/blob/main/%22%D0%95%D1%80%D0%BC%D0%B0%D0%BA%D0%BE%D0%B2_%D0%94%D0%97_1_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашнее задание 1
#
# Soft deadline: **28 декабря 23:59**
# Hard deadline: **9 января 23:59**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Выполните клетку ниже

# %%
# !wget https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv .
# Out:
# --2022-01-09 14:45:38--  https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv
# Resolving web.stanford.edu (web.stanford.edu)... 171.67.215.200, 2607:f6d0:0:925a::ab43:d7c8
# Connecting to web.stanford.edu (web.stanford.edu)|171.67.215.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 44225 (43K) [text/csv]
# Saving to: ‘titanic.csv’
#
# titanic.csv         100%[===================>]  43.19K   145KB/s    in 0.3s
#
# 2022-01-09 14:45:39 (145 KB/s) - ‘titanic.csv’ saved [44225/44225]
#
# --2022-01-09 14:45:39--  http://./
# Resolving . (.)... failed: No address associated with hostname.
# wget: unable to resolve host address ‘.’
# FINISHED --2022-01-09 14:45:39--
# Total wall clock time: 0.9s
# Downloaded: 1 files, 43K in 0.3s (145 KB/s)

# %% [markdown]
# ## Задание 1
# Прочитайте файл в датафрейм, так, чтобы появились корректные колонки без каких-либо дополнительных действий, и отобразите первые 5 строчек

# %%
# ваш код тут
titanic_DF= pd.read_csv('titanic.csv')
titanic_DF.head(5)
# Out:
#    Survived  Pclass  ... Parents/Children Aboard     Fare
# 0         0       3  ...                       0   7.2500
# 1         1       1  ...                       0  71.2833
# 2         1       3  ...                       0   7.9250
# 3         1       1  ...                       0  53.1000
# 4         0       3  ...                       0   8.0500
#
# [5 rows x 8 columns]

# %% [markdown]
# ## Задание 2
# Вывести имена всех выживших детей и их количество (у детей возраст < 18)

# %%
# ваш код тут

titanic_Survived_child = titanic_DF[(titanic_DF['Survived']==1) & (titanic_DF['Age']<18)]
titanic_Survived_child
# Out:
#      Survived  Pclass  ... Parents/Children Aboard     Fare
# 9           1       2  ...                       0  30.0708
# 10          1       3  ...                       1  16.7000
# 22          1       3  ...                       0   8.0292
# 39          1       3  ...                       0  11.2417
# 42          1       2  ...                       2  41.5792
# ..        ...     ...  ...                     ...      ...
# 826         1       3  ...                       0  14.4542
# 827         1       2  ...                       1  18.7500
# 849         1       1  ...                       1  39.4000
# 865         1       3  ...                       1  11.1333
# 871         1       3  ...                       0   7.2250
#
# [65 rows x 8 columns]

# %%
print('имена выживших детей')
titanic_Survived_child['Name']
# Out:
# имена выживших детей
# 9           Mrs. Nicholas (Adele Achem) Nasser
# 10              Miss. Marguerite Rut Sandstrom
# 22                          Miss. Anna McGowan
# 39                  Miss. Jamila Nicola-Yarred
# 42     Miss. Simonne Marie Anne Andree Laroche
#                         ...
# 826     Mrs. Antoni (Selini Alexander) Yasbeck
# 827             Master. George Sibley Richards
# 849                   Miss. Mary Conover Lines
# 865             Master. Harold Theodor Johnson
# 871                   Miss. Adele Kiamie Najib
# Name: Name, Length: 65, dtype: object

# %%
print('количество выживших детей')
titanic_Survived_child['Name'].count()
# Out:
# количество выживших детей
# 65

# %% [markdown]
# ## Задание 3
# Сделайте индексом колонку Name

# %%
# ваш код тут

titanic_Survived_child.set_index('Name')
# Out:
#                                          Survived  ...     Fare
# Name                                               ...
# Mrs. Nicholas (Adele Achem) Nasser              1  ...  30.0708
# Miss. Marguerite Rut Sandstrom                  1  ...  16.7000
# Miss. Anna McGowan                              1  ...   8.0292
# Miss. Jamila Nicola-Yarred                      1  ...  11.2417
# Miss. Simonne Marie Anne Andree Laroche         1  ...  41.5792
# ...                                           ...  ...      ...
# Mrs. Antoni (Selini Alexander) Yasbeck          1  ...  14.4542
# Master. George Sibley Richards                  1  ...  18.7500
# Miss. Mary Conover Lines                        1  ...  39.4000
# Master. Harold Theodor Johnson                  1  ...  11.1333
# Miss. Adele Kiamie Najib                        1  ...   7.2250
#
# [65 rows x 7 columns]

# %% [markdown]
# ## Задание 4
# Выберите возраст, и колонку Survived всех людей у которых в имени есть слово Henry

# %%
# ваш код тут

titanic_Survived_Henry = titanic_DF[(titanic_DF['Name'].str.contains('Henry')) & (titanic_DF['Survived']==1)]
titanic_Survived_Henry
# Out:
#      Survived  Pclass  ... Parents/Children Aboard      Fare
# 51          1       1  ...                       0   76.7292
# 208         1       1  ...                       0   31.0000
# 229         1       1  ...                       0   83.4750
# 269         1       3  ...                       0    0.0000
# 332         1       1  ...                       0  133.6500
# 345         1       3  ...                       0   16.1000
# 627         1       1  ...                       0   30.0000
# 642         1       1  ...                       0   76.7292
# 657         1       1  ...                       0  133.6500
# 722         1       2  ...                       0   21.0000
#
# [10 rows x 8 columns]

# %%
titanic_Survived_Henry.loc[:,['Survived','Age']]
# titanic_Survived_Henry.loc[:,['Survived','Age','Name']] если надо с именем
# Out:
#      Survived   Age
# 51          1  49.0
# 208         1  40.0
# 229         1  35.0
# 269         1  25.0
# 332         1  42.0
# 345         1  34.0
# 627         1  80.0
# 642         1  48.0
# 657         1  50.0
# 722         1  30.0

# %% [markdown]
# ## Задание 5
# Посчитайте среднюю выживаемость в зависимости от приставки в имени.
#
# *Подсказка: приставка -- первое слово, или то слово, которое обозначается через точку (см результат для Henry). Воспользуйтесь groupby и строковыми методами работы .str*

# %%
 titanic_DF.count()
# Out:
# Survived                   887
# Pclass                     887
# Name                       887
# Sex                        887
# Age                        887
# Siblings/Spouses Aboard    887
# Parents/Children Aboard    887
# Fare                       887
# dtype: int64

# %%
# ваш код тут
titanic_Survived_Mrs = titanic_DF[(titanic_DF['Name'].str.contains('Mrs.')) & (titanic_DF['Survived']==1)]
titanic_Survived_Mrs.count()
print('число выживших Mrs',titanic_Survived_Mrs.count())
x = titanic_Survived_Mrs.count()/titanic_DF.count()*100
print('Средняя выживаемость Mrs', x )
# Out:
# число выживших Mrs Survived                   99
# Pclass                     99
# Name                       99
# Sex                        99
# Age                        99
# Siblings/Spouses Aboard    99
# Parents/Children Aboard    99
# Fare                       99
# dtype: int64
# Средняя выживаемость Mrs Survived                   11.161218
# Pclass                     11.161218
# Name                       11.161218
# Sex                        11.161218
# Age                        11.161218
# Siblings/Spouses Aboard    11.161218
# Parents/Children Aboard    11.161218
# Fare                       11.161218
# dtype: float64

# %%
titanic_Survived_Mr = titanic_DF[(titanic_DF['Name'].str.contains('Mr.' or 'Dr.')) & (titanic_DF['Survived']==1)]
titanic_Survived_Mr.count()
print('число выживших Mrs',titanic_Survived_Mr.count())
x = titanic_Survived_Mr.count()/titanic_DF.count()*100
print('Средняя выживаемость Mrs', x )
# Out:
# число выживших Mrs Survived                   180
# Pclass                     180
# Name                       180
# Sex                        180
# Age                        180
# Siblings/Spouses Aboard    180
# Parents/Children Aboard    180
# Fare                       180
# dtype: int64
# Средняя выживаемость Mrs Survived                   20.293123
# Pclass                     20.293123
# Name                       20.293123
# Sex                        20.293123
# Age                        20.293123
# Siblings/Spouses Aboard    20.293123
# Parents/Children Aboard    20.293123
# Fare                       20.293123
# dtype: float64

# %% [markdown]
# ## Задание 6
# Постройте общее распределение выживших и невыживших

# %%
# ваш код тут
(titanic_DF.Survived.value_counts(normalize=True) * 100).plot.barh().set_title("общее распределение выживших и невыживших пассажиров")
# Out:
# Text(0.5, 1.0, 'общее распределение выживших и невыживших пассажиров')

# %% [markdown]
# ## Задание 7
# С помощью pairplot постройте попарные график с раскраской по полю Survived.

# %%
# ваш код тут
sns.pairplot(titanic_DF, hue="Survived")
plt.show()

# %% [markdown]
# ## Задание 9
# Точки накладываются друг на друга, не очень понятно что происходит, найдите способ отобразить точки с параметром прозрачности и снова постройте pairplot.
#
# *Подсказка: гугл.*

# %%
# ваш код тут
sns.pairplot(titanic_DF, hue="Survived" ,  plot_kws={'alpha':0.1})
plt.show()

# %% [markdown]
# ## Задание 10
# Теперь мы лучше видим концентрацию точек, давайте посмотрим более детально на разрез возраст/класс/пол пассажира.
#
# Сделайте FacetGrid в разбиении по Pclass.
#
# Вы можете найти полезным вот [этот материал](https://nagornyy.me/courses/data-science/intro-to-seaborn/#facet-grid)

# %%
# ваш код тут
g = sns.FacetGrid(titanic_DF,col='Pclass',)
g.map(plt.hist,"Age")
g.add_legend()
plt.show()

g = sns.FacetGrid(titanic_DF,col='Pclass')
g.map(plt.hist,"Sex")
plt.show()

# %% [markdown]
# ## Задание 11
# Постройте еще какой-нибудь интересный по вашему мнению график, приведенный в материале выше. Объясните почему вы построили именно его.

# %% [markdown]
# Рассматриваю следующие зависимости, лияющие на выживаемость:
# Гистограммы выживших и нет, в зависимости от класса   -  как влияет класс пассажира на его выживаемость при катастрофе
#
# Гистограммы выживших и нет, в зависимости от возраста  -  выявление того, как влияет возраст пассажира на его выживаемомть

# %%
# ваш код тут
g = sns.FacetGrid(titanic_DF,col='Survived',)
g.map(plt.hist,"Pclass")
g.add_legend()
plt.show()

g = sns.FacetGrid(titanic_DF,col='Survived',)
g.map(plt.hist,"Age")
g.add_legend()
plt.show()

# %% [markdown]
# ## Задание 12
# Постройте сводную таблицу (pivot_table), отражающую долю выживших, класс пассажира и его пол, используя groupby + unstack

# %%
# ваш код тут

titanic_DF_Pivot = titanic_DF.groupby(['Pclass','Sex'])
titanic_DF_Pivot2 = titanic_DF_Pivot2 = titanic_DF_Pivot.Survived.mean().unstack(fill_value=0)
titanic_DF_Pivot2
# Out:
# Sex       female      male
# Pclass
# 1       0.968085  0.368852
# 2       0.921053  0.157407
# 3       0.500000  0.137026

# %% [markdown]
# ## Задание 13
# Постройте сводную таблицу (pivot_table), отражающую долю выживших, класс пассажира и его пол, используя метод pivot_table

# %%
titanic_DF_Pivot3 = pd.pivot_table(titanic_DF, index=['Pclass','Sex'] )
titanic_DF_Pivot3
# Out:
#                      Age        Fare  ...  Siblings/Spouses Aboard  Survived
# Pclass Sex                            ...
# 1      female  35.255319  106.125798  ...                 0.553191  0.968085
#        male    41.511639   67.226127  ...                 0.311475  0.368852
# 2      female  28.980263   21.970121  ...                 0.486842  0.921053
#        male    30.493796   19.741782  ...                 0.342593  0.157407
# 3      female  22.135417   16.118810  ...                 0.895833  0.500000
#        male    26.470612   12.695466  ...                 0.504373  0.137026
#
# [6 rows x 5 columns]

# %% [markdown]
# ## Задание 14
# Попробуйте найти еще какой-нибудь фактор выживаемости с помощью доступных вам сейчас методов.
#
# Т.е, используя выборки, аггрегацию, графики

# %% [markdown]
# Рассматриваю ниже 3 фактора влияющие на выживаемость:
# 1.   выживаемость пассажиров в зависимости от стоимости приобретенного билета
# 2.   зависимость выживаемости по признаку - Родители/Дети на борту
# 3.   зависимость выживаемости по признаку - Братья и сестры/супруги на борту

# %%
g = sns.FacetGrid(titanic_DF,col='Survived',)
g.map(plt.hist,"Fare")
g.add_legend()
plt.show()

# %%
g = sns.FacetGrid(titanic_DF,col='Survived')
g.map(plt.hist,"Parents/Children Aboard")
g.add_legend()
plt.show()

# %%
g = sns.FacetGrid(titanic_DF,col='Survived')
g.map(plt.hist,"Siblings/Spouses Aboard")
g.add_legend()
plt.show()
